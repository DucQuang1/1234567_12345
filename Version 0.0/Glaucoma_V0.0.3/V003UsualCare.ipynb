# %% [markdown]
# #Van Gestel's Simulation Model in Python Simpy
#
# Here is the main Program for the simulation model.
#
# It is OO so most of operations are done outside of this file.
#
# Number of Iterations: 20
#
# Subjects (patients) per iteration: 3000
#
# QALY is calculated based on VFQ score (VFQ-25 questionaire)

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 23 15:58:54 2015

@author: Martin Nguyen
"""

#error checking measures 
import matplotlib.pyplot as plt
masterListforReplications = [[0 for j in range(0)] for i in range(100)]
from PlottingSystemClass import PlottingSystem
from SimulationSystemClass import SimulationSystem
plottingsystem = PlottingSystem(plt)
order = 1

# %% [markdown]
# ### The main code is here
# It is run for 20 rounds
# 7 plots are produced for each iteration

# %%
# %matplotlib inline
for i in range(30):
    sysSimulation = SimulationSystem(3000,"PatientList/Patients_list_{}.csv".format(i))
    sysSimulation.SystemSimulation()
    plottingsystem.plot(sysSimulation,order,i,masterListforReplications)
    order += (7*1) 
    del sysSimulation 
    #del plottingsystem
print order
# Out:
# CURRENT ITERATION: 0
# Average QALY: 12.6791878957
# Average Medical Cost: 25869.150425
# Average MD: -12.4235693102
#
# CURRENT ITERATION: 1
# Average QALY: 12.6501971791
# Average Medical Cost: 26476.293925
# Average MD: -12.5523895983
#
# CURRENT ITERATION: 2
# Average QALY: 12.6365115094
# Average Medical Cost: 26284.083075
# Average MD: -12.6646875537
#
# CURRENT ITERATION: 3
# Average QALY: 12.6396233292
# Average Medical Cost: 26598.084475
# Average MD: -12.6617515407
#
# CURRENT ITERATION: 4
# Average QALY: 12.6448234551
# Average Medical Cost: 26738.2870933
# Average MD: -12.5891975545
#
# CURRENT ITERATION: 5
# Average QALY: 12.6772671636
# Average Medical Cost: 26336.05788
# Average MD: -12.4234046494
#
# CURRENT ITERATION: 6
# Average QALY: 12.6184038226
# Average Medical Cost: 26680.6397433
# Average MD: -12.7073166253
#
# CURRENT ITERATION: 7
# Average QALY: 12.6291048843
# Average Medical Cost: 26763.79719
# Average MD: -12.6690377137
#
# CURRENT ITERATION: 8
# Average QALY: 12.6493112509
# Average Medical Cost: 26271.2060783
# Average MD: -12.5161670987
#
# CURRENT ITERATION: 9
# Average QALY: 12.660329262
# Average Medical Cost: 26223.72695
# Average MD: -12.5457877321
#
# CURRENT ITERATION: 10
# Average QALY: 12.6416571316
# Average Medical Cost: 26481.5456733
# Average MD: -12.6477500193
#
# CURRENT ITERATION: 11
# Average QALY: 12.6859681188
# Average Medical Cost: 25841.174125
# Average MD: -12.4102209499
#
# CURRENT ITERATION: 12
# Average QALY: 12.64667954
# Average Medical Cost: 26288.8204267
# Average MD: -12.5760831811
#
# CURRENT ITERATION: 13
# Average QALY: 12.6307529893
# Average Medical Cost: 26059.9527583
# Average MD: -12.6577858348
#
# CURRENT ITERATION: 14
# Average QALY: 12.6706708079
# Average Medical Cost: 26173.7774
# Average MD: -12.5203617168
#
# CURRENT ITERATION: 15
# Average QALY: 12.6753672044
# Average Medical Cost: 26008.7881767
# Average MD: -12.4801330528
#
# CURRENT ITERATION: 16
# Average QALY: 12.6511781851
# Average Medical Cost: 26417.0198133
# Average MD: -12.5677185381
#
# CURRENT ITERATION: 17
# Average QALY: 12.6556394289
# Average Medical Cost: 26227.0073117
# Average MD: -12.5461615942
#
# CURRENT ITERATION: 18
# Average QALY: 12.6425011725
# Average Medical Cost: 26606.1046117
# Average MD: -12.6342753935
#
# CURRENT ITERATION: 19
# Average QALY: 12.6774721369
# Average Medical Cost: 26104.7507067
# Average MD: -12.4505929332
#
# CURRENT ITERATION: 20
# Average QALY: 12.6741466538
# Average Medical Cost: 26088.1591067
# Average MD: -12.4613607508
#
# CURRENT ITERATION: 21
# Average QALY: 12.6520972792
# Average Medical Cost: 26317.7472183
# Average MD: -12.581522755
#
# CURRENT ITERATION: 22
# Average QALY: 12.655338066
# Average Medical Cost: 26192.6234067
# Average MD: -12.583466321
#
# CURRENT ITERATION: 23
# Average QALY: 12.669818976
# Average Medical Cost: 26205.9198183
# Average MD: -12.4601856158
#
# CURRENT ITERATION: 24
# Average QALY: 12.6777322121
# Average Medical Cost: 26080.8160183
# Average MD: -12.4476974097
#
# CURRENT ITERATION: 25
# Average QALY: 12.6402322048
# Average Medical Cost: 26605.320275
# Average MD: -12.6225302798
#
# CURRENT ITERATION: 26
# Average QALY: 12.6272576436
# Average Medical Cost: 26638.3001083
# Average MD: -12.6691753799
#
# CURRENT ITERATION: 27
# Average QALY: 12.621232273
# Average Medical Cost: 26843.4383
# Average MD: -12.697298531
#
# CURRENT ITERATION: 28
# Average QALY: 12.6510062128
# Average Medical Cost: 26071.843015
# Average MD: -12.5972027826
#
# CURRENT ITERATION: 29
# Average QALY: 12.6217740687
# Average Medical Cost: 26930.49648
# Average MD: -12.7355389896
#
# 218
# C:\Users\Martin Nguyen\Anaconda\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
