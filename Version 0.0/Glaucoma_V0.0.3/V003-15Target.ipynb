# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 23 15:58:54 2015

@author: Martin Nguyen
"""

#error checking measures 
import matplotlib.pyplot as plt
masterListforReplications = [[0 for j in range(0)] for i in range(100)]
from PlottingSystemClass import PlottingSystem
from SimulationSystemClass import SimulationSystem
plottingsystem = PlottingSystem(plt)
order = 1
# %matplotlib inline
for i in range(30):
    sysSimulation = SimulationSystem(3000,"PatientList/Patients_list_{}.csv".format(i))
    sysSimulation.SystemSimulation()
    plottingsystem.plot(sysSimulation,order,i,masterListforReplications)
    order += (7*1) 
    del sysSimulation 
    #del plottingsystem
print order
# Out:
# CURRENT ITERATION: 0
# Average QALY: 12.7417358511
# Average Medical Cost: 24565.2768483
# Average MD: -11.9397088031
#
# CURRENT ITERATION: 1
# Average QALY: 12.7122530729
# Average Medical Cost: 25258.6582483
# Average MD: -12.1003679444
#
# CURRENT ITERATION: 2
# Average QALY: 12.7028577599
# Average Medical Cost: 24971.3227883
# Average MD: -12.2021579964
#
# CURRENT ITERATION: 3
# Average QALY: 12.6950243617
# Average Medical Cost: 25430.758575
# Average MD: -12.2167608389
#
# CURRENT ITERATION: 4
# Average QALY: 12.7048372774
# Average Medical Cost: 25476.617835
# Average MD: -12.1285785502
#
# CURRENT ITERATION: 5
# Average QALY: 12.7360032118
# Average Medical Cost: 25039.6505183
# Average MD: -11.9593771374
#
# CURRENT ITERATION: 6
# Average QALY: 12.6790472268
# Average Medical Cost: 25675.350945
# Average MD: -12.2812896361
#
# CURRENT ITERATION: 7
# Average QALY: 12.6861835195
# Average Medical Cost: 25528.257815
# Average MD: -12.2165047668
#
# CURRENT ITERATION: 8
# Average QALY: 12.713143152
# Average Medical Cost: 24949.7296217
# Average MD: -12.0534681357
#
# CURRENT ITERATION: 9
# Average QALY: 12.723551623
# Average Medical Cost: 25045.4245317
# Average MD: -12.0851324185
#
# CURRENT ITERATION: 10
# Average QALY: 12.705932846
# Average Medical Cost: 25275.6454767
# Average MD: -12.1852519689
#
# CURRENT ITERATION: 11
# Average QALY: 12.749986898
# Average Medical Cost: 24543.1553217
# Average MD: -11.9325637542
#
# CURRENT ITERATION: 12
# Average QALY: 12.703924673
# Average Medical Cost: 25139.19172
# Average MD: -12.1448985562
#
# CURRENT ITERATION: 13
# Average QALY: 12.68631116
# Average Medical Cost: 24943.848665
# Average MD: -12.2216710211
#
# CURRENT ITERATION: 14
# Average QALY: 12.7277239936
# Average Medical Cost: 25131.0261633
# Average MD: -12.0829441711
#
# CURRENT ITERATION: 15
# Average QALY: 12.7324515793
# Average Medical Cost: 24789.74997
# Average MD: -12.0508056499
#
# CURRENT ITERATION: 16
# Average QALY: 12.7123445634
# Average Medical Cost: 25381.5081267
# Average MD: -12.1244917045
#
# CURRENT ITERATION: 17
# Average QALY: 12.7208441803
# Average Medical Cost: 25146.8357417
# Average MD: -12.0686052045
#
# CURRENT ITERATION: 18
# Average QALY: 12.704259641
# Average Medical Cost: 25492.683425
# Average MD: -12.1930405952
#
# CURRENT ITERATION: 19
# Average QALY: 12.738785216
# Average Medical Cost: 24856.43276
# Average MD: -11.9851077487
#
# CURRENT ITERATION: 20
# Average QALY: 12.7389108385
# Average Medical Cost: 24919.1861717
# Average MD: -11.9881581631
#
# CURRENT ITERATION: 21
# Average QALY: 12.7155435348
# Average Medical Cost: 25206.02802
# Average MD: -12.1178234523
#
# CURRENT ITERATION: 22
# Average QALY: 12.7145609248
# Average Medical Cost: 25084.225595
# Average MD: -12.1432381898
#
# CURRENT ITERATION: 23
# Average QALY: 12.7315780667
# Average Medical Cost: 24986.0954467
# Average MD: -11.9773081935
#
# CURRENT ITERATION: 24
# Average QALY: 12.7470827606
# Average Medical Cost: 24976.8791983
# Average MD: -11.9542039203
#
# CURRENT ITERATION: 25
# Average QALY: 12.7008915348
# Average Medical Cost: 25464.443585
# Average MD: -12.1772627557
#
# CURRENT ITERATION: 26
# Average QALY: 12.6886043602
# Average Medical Cost: 25408.80419
# Average MD: -12.2042907892
#
# CURRENT ITERATION: 27
# Average QALY: 12.6812875525
# Average Medical Cost: 25808.73757
# Average MD: -12.2741431685
#
# CURRENT ITERATION: 28
# Average QALY: 12.7116373643
# Average Medical Cost: 25072.4003733
# Average MD: -12.1319196047
#
# CURRENT ITERATION: 29
# Average QALY: 12.6843443365
# Average Medical Cost: 25673.996435
# Average MD: -12.2718334306
#
# 211
# C:\Users\Martin Nguyen\Anaconda\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
