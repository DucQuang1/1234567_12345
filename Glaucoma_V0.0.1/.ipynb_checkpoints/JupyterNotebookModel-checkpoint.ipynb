# %% [markdown]
# #Van Gestel's Simulation Model in Python Simpy
#
# Here is the main Program for the simulation model.
#
# It is OO so most of operations are done outside of this file.
#
# Number of Iterations: 20
#
# Subjects (patients) per iteration: 3000
#
# QALY is calculated based on VFQ score (VFQ-25 questionaire)

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 23 15:58:54 2015

@author: Martin Nguyen
"""

#error checking measures 
import matplotlib.pyplot as plt
masterListforReplications = [[0 for j in range(0)] for i in range(100)]
from PlottingSystemClass import PlottingSystem
from SimulationSystemClass import SimulationSystem
plottingsystem = PlottingSystem(plt)
order = 1

# %% [markdown]
# ### The main code is here
# It is run for 20 rounds
# 7 plots are produced for each iteration

# %%
# %matplotlib inline
for i in range(20):
    sysSimulation = SimulationSystem(3000,"PatientList/Patients_list_{}.csv".format(i))
    sysSimulation.SystemSimulation()
    plottingsystem.plot(sysSimulation,order,i,masterListforReplications)
    order += (7*1) 
    del sysSimulation 
    #del plottingsystem
print order
# Out:
# CURRENT ITERATION: 0
# Average QALY: 12.460990201
# Average Medical Cost: 26338.6413773
# Average MD: -13.8066848965
#
# CURRENT ITERATION: 1
# Average QALY: 12.4177131021
# Average Medical Cost: 27162.8710447
# Average MD: -14.0707038892
#
# CURRENT ITERATION: 2
# Average QALY: 12.4113600063
# Average Medical Cost: 26982.068814
# Average MD: -14.0192832922
#
# CURRENT ITERATION: 3
# Average QALY: 12.4077257643
# Average Medical Cost: 27011.750628
# Average MD: -14.0876988403
#
# CURRENT ITERATION: 4
# Average QALY: 12.3912246592
# Average Medical Cost: 27348.9219013
# Average MD: -14.1986864218
#
# CURRENT ITERATION: 5
# Average QALY: 12.4417164631
# Average Medical Cost: 26682.978438
# Average MD: -13.9829250222
#
# CURRENT ITERATION: 6
# Average QALY: 12.4088220148
# Average Medical Cost: 27077.7467527
# Average MD: -14.1023136481
#
# CURRENT ITERATION: 7
# Average QALY: 12.4317603508
# Average Medical Cost: 26842.74448
# Average MD: -13.9932941603
#
# CURRENT ITERATION: 8
# Average QALY: 12.4102086911
# Average Medical Cost: 27222.069858
# Average MD: -14.1347434183
#
# CURRENT ITERATION: 9
# Average QALY: 12.4309140612
# Average Medical Cost: 26770.8753627
# Average MD: -14.030350714
#
# CURRENT ITERATION: 10
# Average QALY: 12.4344579729
# Average Medical Cost: 26799.7779267
# Average MD: -13.9088506314
#
# CURRENT ITERATION: 11
# Average QALY: 12.4438393019
# Average Medical Cost: 26704.8215973
# Average MD: -13.9167448989
#
# CURRENT ITERATION: 12
# Average QALY: 12.4474148581
# Average Medical Cost: 26815.545862
# Average MD: -13.8523038127
#
# CURRENT ITERATION: 13
# Average QALY: 12.4402844172
# Average Medical Cost: 26602.9216053
# Average MD: -14.0001449075
#
# CURRENT ITERATION: 14
# Average QALY: 12.4440204612
# Average Medical Cost: 26433.348048
# Average MD: -13.9350136805
#
# CURRENT ITERATION: 15
# Average QALY: 12.3729809742
# Average Medical Cost: 27297.3088087
# Average MD: -14.2780372702
#
# CURRENT ITERATION: 16
# Average QALY: 12.4345766416
# Average Medical Cost: 27033.5027293
# Average MD: -13.9666348069
#
# CURRENT ITERATION: 17
# Average QALY: 12.4191634046
# Average Medical Cost: 26860.3833107
# Average MD: -14.0802951914
#
# CURRENT ITERATION: 18
# Average QALY: 12.4115009723
# Average Medical Cost: 26910.0784333
# Average MD: -14.0589408421
#
# CURRENT ITERATION: 19
# Average QALY: 12.3879106485
# Average Medical Cost: 27392.381145
# Average MD: -14.171723378
#
# 162
