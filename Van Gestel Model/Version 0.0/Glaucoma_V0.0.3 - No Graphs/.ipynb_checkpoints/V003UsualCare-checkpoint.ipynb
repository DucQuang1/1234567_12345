# %% [markdown]
# #Van Gestel's Simulation Model in Python Simpy for Presentation
#
# Here is the main Program for the simulation model.
#
# It is OO so most of operations are done outside of this file.
#
# Number of Iterations: 2
#
# Subjects (patients) per iteration: 3000
#
# QALY is calculated based on VFQ score (VFQ-25 questionaire)

# %%
#error checking measures 
import csv 
import matplotlib.pyplot as plt
numberofGraphs = 15
def csv_dict_writer(path, fieldnames, data):
    with open(path, "wb") as out_file:
        writer = csv.DictWriter(out_file, delimiter=',', fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)
masterListforReplications = []
field_names = "QALY,TotalCost".split(",")
from PlottingSystemClass import PlottingSystem
from SimulationSystemClass import SimulationSystem
plottingsystem = PlottingSystem(plt)
order = 1

# %% [markdown]
# ### The main code is here
# It is run for 20 rounds
# 7 plots are produced for each iteration

# %%
# %matplotlib inline
for i in range(1):
    sysSimulation = SimulationSystem(3000,"PatientList/Patients_list_{}.csv".format(i))
    sysSimulation.SystemSimulation()
    plottingsystem.plot(sysSimulation,order,i,masterListforReplications)
    order += (numberofGraphs*1) 
    del sysSimulation 
print order 
csv_dict_writer("MList.csv",field_names,masterListforReplications)
# Out:
# CURRENT ITERATION: 0
# Average QALY: 12.6055313044
# Average Medical Cost: 26238.3869333
# Average MD: -12.7521039959
#
# Patient 0: List of Medication Progression is [0, 1, 2, 2, 3, 3, 3, 3, 3, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 22, 22]
# Patient 0: List of Final Medication Amount is [1, 1, 5, 3, 1]
# Patient 1: List of Medication Progression is [0, 1, 1, 6, 6, 8, 8, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30]
# Patient 1: List of Final Medication Amount is [7, 5, 3, 0, 1]
# Patient 2: List of Medication Progression is [0, 1, 1, 6, 6, 6, 6, 6, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11]
# Patient 2: List of Final Medication Amount is [7, 5, 0, 3, 1]
# Patient 3: List of Medication Progression is [0, 1, 1, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]
# Patient 3: List of Final Medication Amount is [5, 3, 1, 0, 0]
# Patient 4: List of Medication Progression is [0, 1, 1, 6, 6, 6, 6, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 10, 10, 10, 10, 10, 10, 10, 10, 10, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30]
# Patient 4: List of Final Medication Amount is [8, 6, 4, 0, 2]
# 16

# %% [markdown]
# <img src = "Images/Capture.JPG">
