# %% [markdown]
# #Van Gestel's Simulation Model in Python Simpy
#
# Here is the main Program for the simulation model.
#
# It is OO so most of operations are done outside of this file.
#
# Number of Iterations: 20
#
# Subjects (patients) per iteration: 3000
#
# QALY is calculated based on VFQ score (VFQ-25 questionaire)

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 23 15:58:54 2015

@author: Martin Nguyen
"""

#error checking measures 
import matplotlib.pyplot as plt
masterListforReplications = [[0 for j in range(0)] for i in range(100)]
from PlottingSystemClass import PlottingSystem
from SimulationSystemClass import SimulationSystem
plottingsystem = PlottingSystem(plt)
order = 1

# %% [markdown]
# ### The main code is here
# It is run for 20 rounds
# 7 plots are produced for each iteration

# %%
# %matplotlib inline
for i in range(30):
    sysSimulation = SimulationSystem(3000,"PatientList/Patients_list_{}.csv".format(i))
    sysSimulation.SystemSimulation()
    plottingsystem.plot(sysSimulation,order,i,masterListforReplications)
    order += (7*1) 
    del sysSimulation 
    #del plottingsystem
print order
# Out:
# CURRENT ITERATION: 0
# Average QALY: 12.5916430241
# Average Medical Cost: 25599.8343533
# Average MD: -12.8170234633
#
# CURRENT ITERATION: 1
# Average QALY: 12.5649874709
# Average Medical Cost: 26242.6354133
# Average MD: -12.9189259677
#
# CURRENT ITERATION: 2
# Average QALY: 12.5536554182
# Average Medical Cost: 26123.8761067
# Average MD: -13.046394739
#
# CURRENT ITERATION: 3
# Average QALY: 12.5508839772
# Average Medical Cost: 26361.8979983
# Average MD: -13.0176147881
#
# CURRENT ITERATION: 4
# Average QALY: 12.563303996
# Average Medical Cost: 26494.0145217
# Average MD: -12.9410170824
#
# CURRENT ITERATION: 5
# Average QALY: 12.5979892845
# Average Medical Cost: 26126.3971683
# Average MD: -12.7764967582
#
# CURRENT ITERATION: 6
# Average QALY: 12.5335153713
# Average Medical Cost: 26588.7004533
# Average MD: -13.1070005813
#
# CURRENT ITERATION: 7
# Average QALY: 12.541956896
# Average Medical Cost: 26469.2314433
# Average MD: -13.0318910893
#
# CURRENT ITERATION: 8
# Average QALY: 12.5750134555
# Average Medical Cost: 26060.4930617
# Average MD: -12.860300703
#
# CURRENT ITERATION: 9
# Average QALY: 12.5758950179
# Average Medical Cost: 25982.1710367
# Average MD: -12.9073887017
#
# CURRENT ITERATION: 10
# Average QALY: 12.5549943919
# Average Medical Cost: 26332.986305
# Average MD: -13.0289028629
#
# CURRENT ITERATION: 11
# Average QALY: 12.6107358648
# Average Medical Cost: 25515.603075
# Average MD: -12.7249986511
#
# CURRENT ITERATION: 12
# Average QALY: 12.561653102
# Average Medical Cost: 26091.02887
# Average MD: -12.9531837108
#
# CURRENT ITERATION: 13
# Average QALY: 12.5423195773
# Average Medical Cost: 25925.4421533
# Average MD: -13.0539668421
#
# CURRENT ITERATION: 14
# Average QALY: 12.5804833493
# Average Medical Cost: 26037.289955
# Average MD: -12.9249893687
#
# CURRENT ITERATION: 15
# Average QALY: 12.5856846416
# Average Medical Cost: 25815.6039083
# Average MD: -12.8645495592
#
# CURRENT ITERATION: 16
# Average QALY: 12.5631232126
# Average Medical Cost: 26264.4239567
# Average MD: -12.943757948
#
# CURRENT ITERATION: 17
# Average QALY: 12.5746279855
# Average Medical Cost: 25990.14978
# Average MD: -12.8884076036
#
# CURRENT ITERATION: 18
# Average QALY: 12.5551807694
# Average Medical Cost: 26356.1933283
# Average MD: -13.0073539565
#
# CURRENT ITERATION: 19
# Average QALY: 12.5897315666
# Average Medical Cost: 25868.1780117
# Average MD: -12.8150652525
#
# CURRENT ITERATION: 20
# Average QALY: 12.5862475003
# Average Medical Cost: 25931.1501933
# Average MD: -12.8315649352
#
# CURRENT ITERATION: 21
# Average QALY: 12.5661620783
# Average Medical Cost: 26132.0137917
# Average MD: -12.9673686673
#
# CURRENT ITERATION: 22
# Average QALY: 12.5678856681
# Average Medical Cost: 25921.0099
# Average MD: -12.9539037619
#
# CURRENT ITERATION: 23
# Average QALY: 12.5901846138
# Average Medical Cost: 25996.0258467
# Average MD: -12.8122613868
#
# CURRENT ITERATION: 24
# Average QALY: 12.5973423884
# Average Medical Cost: 25842.0289917
# Average MD: -12.7948058635
#
# CURRENT ITERATION: 25
# Average QALY: 12.5565744575
# Average Medical Cost: 26379.256045
# Average MD: -12.9842807434
#
# CURRENT ITERATION: 26
# Average QALY: 12.5423843174
# Average Medical Cost: 26443.0918383
# Average MD: -13.0350660488
#
# CURRENT ITERATION: 27
# Average QALY: 12.5381815089
# Average Medical Cost: 26622.7219967
# Average MD: -13.0716723304
#
# CURRENT ITERATION: 28
# Average QALY: 12.5654745838
# Average Medical Cost: 26004.7764183
# Average MD: -12.9646421561
#
# CURRENT ITERATION: 29
# Average QALY: 12.542249814
# Average Medical Cost: 26580.10411
# Average MD: -13.0838719406
#
# 211
