# %% [markdown]
# #Van Gestel's Simulation Model in Python Simpy
#
# Here is the main Program for the simulation model.
#
# It is OO so most of operations are done outside of this file.
#
# Number of Iterations: 20
#
# Subjects (patients) per iteration: 3000
#
# QALY is calculated based on VFQ score (VFQ-25 questionaire)

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat May 23 15:58:54 2015

@author: Martin Nguyen
"""

#error checking measures 
import matplotlib.pyplot as plt
masterListforReplications = [[0 for j in range(0)] for i in range(100)]
from PlottingSystemClass import PlottingSystem
from SimulationSystemClass import SimulationSystem
plottingsystem = PlottingSystem(plt)
order = 1

# %% [markdown]
# ### The main code is here
# It is run for 20 rounds
# 7 plots are produced for each iteration

# %%
# %matplotlib inline
for i in range(20):
    sysSimulation = SimulationSystem(3000,"PatientList/Patients_list_{}.csv".format(i))
    sysSimulation.SystemSimulation()
    plottingsystem.plot(sysSimulation,order,i,masterListforReplications)
    order += (7*1) 
    del sysSimulation 
    #del plottingsystem
print order
# Out:
# CURRENT ITERATION: 0
# Average QALY: 12.4325678823
# Average Medical Cost: 26330.3745513
# Average MD: -13.7862094216
#
# CURRENT ITERATION: 1
# Average QALY: 12.4021500791
# Average Medical Cost: 26587.20679
# Average MD: -13.9238423868
#
# CURRENT ITERATION: 2
# Average QALY: 12.423038277
# Average Medical Cost: 26236.5951493
# Average MD: -13.8339686421
#
# CURRENT ITERATION: 3
# Average QALY: 12.4607065097
# Average Medical Cost: 26109.2696873
# Average MD: -13.621129999
#
# CURRENT ITERATION: 4
# Average QALY: 12.4250437498
# Average Medical Cost: 26397.0436313
# Average MD: -13.8294511854
#
# CURRENT ITERATION: 5
# Average QALY: 12.445943378
# Average Medical Cost: 26167.2902493
# Average MD: -13.7146183739
#
# CURRENT ITERATION: 6
# Average QALY: 12.4269179567
# Average Medical Cost: 26477.9147987
# Average MD: -13.7765631176
#
# CURRENT ITERATION: 7
# Average QALY: 12.4375286994
# Average Medical Cost: 26458.578519
# Average MD: -13.7841184876
#
# CURRENT ITERATION: 8
# Average QALY: 12.4243711605
# Average Medical Cost: 26279.090151
# Average MD: -13.8138575727
#
# CURRENT ITERATION: 9
# Average QALY: 12.4639618349
# Average Medical Cost: 25860.8276427
# Average MD: -13.6305951448
#
# CURRENT ITERATION: 10
# Average QALY: 12.402221965
# Average Medical Cost: 26596.0629307
# Average MD: -14.010219843
#
# CURRENT ITERATION: 11
# Average QALY: 12.4242709185
# Average Medical Cost: 26270.5716247
# Average MD: -13.825971621
#
# CURRENT ITERATION: 12
# Average QALY: 12.4618963338
# Average Medical Cost: 25878.3418627
# Average MD: -13.566396083
#
# CURRENT ITERATION: 13
# Average QALY: 12.4031622176
# Average Medical Cost: 26671.7717573
# Average MD: -13.9709094557
#
# CURRENT ITERATION: 14
# Average QALY: 12.4297422497
# Average Medical Cost: 26192.096041
# Average MD: -13.8603064994
#
# CURRENT ITERATION: 15
# Average QALY: 12.4458837053
# Average Medical Cost: 26111.8670873
# Average MD: -13.7195318657
#
# CURRENT ITERATION: 16
# Average QALY: 12.435867163
# Average Medical Cost: 26051.9147407
# Average MD: -13.7938561258
#
# CURRENT ITERATION: 17
# Average QALY: 12.4520686364
# Average Medical Cost: 25985.7022353
# Average MD: -13.6918644207
#
# CURRENT ITERATION: 18
# Average QALY: 12.4146614857
# Average Medical Cost: 26430.1018567
# Average MD: -13.8760839345
#
# CURRENT ITERATION: 19
# Average QALY: 12.4161316672
# Average Medical Cost: 26166.386388
# Average MD: -13.9001474451
#
# 141
# C:\Users\Martin Nguyen\Anaconda\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
